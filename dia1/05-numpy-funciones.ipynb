# %% [markdown]
# # **FUNCIONES MAS COMUNES DE NUMPY**

# %%
import numpy as np

# %% [markdown]
# # SHAPE Y RESHAPE

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[7, 2],
#        [3, 1],
#        [7, 7]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.ndim
# Out:
# 2

# %%
arr.reshape(1,6)
# Out:
# array([[7, 2, 3, 1, 7, 7]])

# %%
arr.ndim
# Out:
# 2

# %% [markdown]
# # MAX Y ARGMAX

# %%
arr = np.random.randint(1,20,10)
arr
# Out:
# array([12,  9, 15,  7, 10, 19,  3,  5,  7,  6])

# %%
matriz = arr.reshape(2,5)
matriz
# Out:
# array([[12,  9, 15,  7, 10],
#        [19,  3,  5,  7,  6]])

# %%
arr.max()
# Out:
# 19

# %%
matriz.max()
# Out:
# 19

# %%
matriz.max(1)
# Out:
# array([15, 19])

# %%
arr.argmax()
# Out:
# 5

# %% [markdown]
# # MIN Y ARGMIN

# %%
arr.min()
# Out:
# 3

# %%
arr.argmin()
# Out:
# 6

# %%
matriz.min(0)
# Out:
# array([12,  3,  5,  7,  6])

# %% [markdown]
# # SORT

# %%
arr
# Out:
# array([12,  9, 15,  7, 10, 19,  3,  5,  7,  6])

# %%
arr.sort()
arr
# Out:
# array([ 3,  5,  6,  7,  7,  9, 10, 12, 15, 19])

# %% [markdown]
# # MEDIAM

# %%
np.median(arr)
# Out:
# 8.0

# %% [markdown]
# # DESVIACIÓN STANDARD STD

# %%
np.std(arr)
# Out:
# 4.627094120503711

# %% [markdown]
# # VARIANZA VAR

# %%
np.var(arr)
# Out:
# 21.410000000000004
