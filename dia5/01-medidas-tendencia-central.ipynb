# %% [markdown]
# # MEDIDAS DE TENDENCIA CENTRAL

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
penguins_df = sns.load_dataset('penguins')
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# ## MEDIA (MEAN)

# %% [markdown]
# ### USANDO PANDAS DATAFRAME

# %%
penguins_df.bill_depth_mm.mean()
# Out:
# 17.151169590643278

# %% [markdown]
# ### USANDO NUMPY

# %%
np.mean(penguins_df.bill_depth_mm)
# Out:
# 17.151169590643278

# %% [markdown]
# ## MEDIA DE TODOS LOS VALORES

# %%
penguins_df.mean(numeric_only=True)
# Out:
# bill_length_mm         43.921930
# bill_depth_mm          17.151170
# flipper_length_mm     200.915205
# body_mass_g          4201.754386
# dtype: float64

# %% [markdown]
# ## MEDIANA

# %%
penguins_df.bill_depth_mm.median()
# Out:
# 17.3

# %% [markdown]
# ## MODA

# %%
penguins_df.bill_depth_mm.mode()
# Out:
# 0    17.0
# Name: bill_depth_mm, dtype: float64

# %% [markdown]
# ## GRAFICAMOS VALORES DE TENDENCIA CENTRAL

# %%
sns.histplot(
    data=penguins_df,
    x='bill_depth_mm'
)
plt.axvline(
    x=penguins_df.bill_depth_mm.mean(),
    color='red',
    linestyle='dashed',
    linewidth = 2
)
plt.axvline(
    x=penguins_df.bill_depth_mm.median(),
    color='yellow',
    linestyle='dashed',
    linewidth = 2
)
plt.axvline(
    x=penguins_df.bill_depth_mm.mode().values[0],
    color='black',
    linestyle='dashed',
    linewidth = 2
)

# %% [markdown]
# ## Ejercicio:

# %% [markdown]
# ### Media:

# %%
penguins_df.flipper_length_mm.mean()
# Out:
# 200.91520467836258

# %% [markdown]
# ### Mediana:

# %%
penguins_df.flipper_length_mm.median()
# Out:
# 197.0

# %% [markdown]
# ### Moda:

# %%
penguins_df.flipper_length_mm.mode().values[0]
# Out:
# 190.0

# %%
sns.histplot(
    data=penguins_df,
    x='flipper_length_mm'
)
plt.axvline(
    x=penguins_df.flipper_length_mm.mean(),
    color='red',
    linestyle='dashed',
    linewidth = 2
)
plt.axvline(
    x=penguins_df.flipper_length_mm.median(),
    color='yellow',
    linestyle='dashed',
    linewidth = 2
)
plt.axvline(
    x=penguins_df.flipper_length_mm.mode().values[0],
    color='black',
    linestyle='dashed',
    linewidth = 2
)
