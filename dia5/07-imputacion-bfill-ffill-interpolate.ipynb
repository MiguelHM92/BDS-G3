# %% [markdown]
# # IMPUTACIÓN POR PROPAGACIÓN HACIA ADELANTE Y HACIA ATRAS

# %% [markdown]
# ## PROPAGACIÓN HACIA ADELANTE (FFILL)

# %%
import pandas as pd
data = pd.Series([1,None,None,4])
data
# Out:
# 0    1.0
# 1    NaN
# 2    NaN
# 3    4.0
# dtype: float64

# %%
data.ffill()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    4.0
# dtype: float64

# %% [markdown]
# ## PROPAGACIÓN HACIA ATRÁS (BFILL)

# %%
data.bfill()
# Out:
# 0    1.0
# 1    4.0
# 2    4.0
# 3    4.0
# dtype: float64

# %% [markdown]
# ## IMPUTACIÓN POR INTERPOLACIÓN (INTERPOLATE)

# %%
data.interpolate()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# dtype: float64
