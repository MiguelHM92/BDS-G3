# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # COMO CALCULAR EL % DE CORRELACIÓN ENTRE 2 VARIABLES

# %%
x = np.linspace(0, 100, 100)
x
# Out:
# array([  0.        ,   1.01010101,   2.02020202,   3.03030303,
#          4.04040404,   5.05050505,   6.06060606,   7.07070707,
#          8.08080808,   9.09090909,  10.1010101 ,  11.11111111,
#         12.12121212,  13.13131313,  14.14141414,  15.15151515,
#         16.16161616,  17.17171717,  18.18181818,  19.19191919,
#         20.2020202 ,  21.21212121,  22.22222222,  23.23232323,
#         24.24242424,  25.25252525,  26.26262626,  27.27272727,
#         28.28282828,  29.29292929,  30.3030303 ,  31.31313131,
#         32.32323232,  33.33333333,  34.34343434,  35.35353535,
#         36.36363636,  37.37373737,  38.38383838,  39.39393939,
#         40.4040404 ,  41.41414141,  42.42424242,  43.43434343,
#         44.44444444,  45.45454545,  46.46464646,  47.47474747,
#         48.48484848,  49.49494949,  50.50505051,  51.51515152,
#         52.52525253,  53.53535354,  54.54545455,  55.55555556,
#         56.56565657,  57.57575758,  58.58585859,  59.5959596 ,
# ...

# %%
y = x ** 2
y
# Out:
# array([0.00000000e+00, 1.02030405e+00, 4.08121620e+00, 9.18273646e+00,
#        1.63248648e+01, 2.55076013e+01, 3.67309458e+01, 4.99948985e+01,
#        6.52994592e+01, 8.26446281e+01, 1.02030405e+02, 1.23456790e+02,
#        1.46923783e+02, 1.72431385e+02, 1.99979594e+02, 2.29568411e+02,
#        2.61197837e+02, 2.94867871e+02, 3.30578512e+02, 3.68329762e+02,
#        4.08121620e+02, 4.49954086e+02, 4.93827160e+02, 5.39740843e+02,
#        5.87695133e+02, 6.37690032e+02, 6.89725538e+02, 7.43801653e+02,
#        7.99918376e+02, 8.58075707e+02, 9.18273646e+02, 9.80512193e+02,
#        1.04479135e+03, 1.11111111e+03, 1.17947148e+03, 1.24987246e+03,
#        1.32231405e+03, 1.39679625e+03, 1.47331905e+03, 1.55188246e+03,
#        1.63248648e+03, 1.71513111e+03, 1.79981635e+03, 1.88654219e+03,
#        1.97530864e+03, 2.06611570e+03, 2.15896337e+03, 2.25385165e+03,
#        2.35078053e+03, 2.44975003e+03, 2.55076013e+03, 2.65381084e+03,
# ...

# %% [markdown]
# # GRAFICO DE CORRELACIÓN ENTRE X y Y

# %%
sns.scatterplot(x=x,y=y)
# Out:
# <Axes: >

# %% [markdown]
# # CALCULO DE CORRELACIÓN

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.96764439],
#        [0.96764439, 1.        ]])

# %% [markdown]
# ## COEFICIENTE DE CORRELACIÓN DE PEARSON
# [Wikipedia](https://es.wikipedia.org/wiki/Coeficiente_de_correlaci%C3%B3n_de_Pearson)

# %% [markdown]
# # ANALISIS DE CORRELACIONES PARA EL DATASET DE PENGUINS

# %%
penguins_df = sns.load_dataset("penguins")
penguins_df.dropna(inplace=True)
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
np.corrcoef(penguins_df.bill_length_mm, penguins_df.bill_depth_mm)
# Out:
# array([[ 1.        , -0.22862564],
#        [-0.22862564,  1.        ]])

# %%
np.corrcoef(penguins_df.flipper_length_mm, penguins_df.body_mass_g)
# Out:
# array([[1.       , 0.8729789],
#        [0.8729789, 1.       ]])

# %%
penguins_df.corr(numeric_only=True)
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000

# %% [markdown]
# # GRAFICAMOS UN MAPA DE CALOR PARA LAS CORRELACIONES

# %%
sns.heatmap(
    data=penguins_df.corr(numeric_only=True),
    cmap=sns.diverging_palette(20,230,as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    cbar_kws={"shrink":0.5},
    annot=True
)
# Out:
# <Axes: >

# %%
sns.clustermap(
    data=penguins_df.corr(numeric_only=True),
    cmap=sns.diverging_palette(20,230,as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    cbar_kws={"shrink":0.5},
    annot=True
)

# %% [markdown]
# # CORRELACIONES CON VARIABLES CATEGORICAS

# %%
penguins_df = (
    penguins_df
    .assign(
        numeric_sex=lambda df: df.sex.replace(['Female','Male'],[0,1])
    )
)
penguins_df
# Out:
# <ipython-input-14-55cc8d5d6269>:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_sex=lambda df: df.sex.replace(['Female','Male'],[0,1])
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# ...

# %%
sns.clustermap(
    data=penguins_df.corr(numeric_only=True),
    cmap=sns.diverging_palette(20,230,as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    cbar_kws={"shrink":0.5},
    annot=True
)

# %% [markdown]
# ### Ejercicio:

# %%
penguins_df = (
    penguins_df
    .assign(
        numeric_sex=lambda df: df.sex.replace(['Female','Male'],[0,1]),
        numeric_species=lambda df: df.species.replace(['Adelie','Chinstrap','Gentoo'],[0,1,2]),
        numeric_island=lambda df: df.island.replace(['Biscoe','Dream','Torgersen'],[0,1,2])
    )
)
penguins_df
# Out:
# <ipython-input-18-29f2563a62c0>:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_sex=lambda df: df.sex.replace(['Female','Male'],[0,1]),
# <ipython-input-18-29f2563a62c0>:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_species=lambda df: df.species.replace(['Adelie','Chinstrap','Gentoo'],[0,1,2]),
# ...

# %%
sns.clustermap(
    data=penguins_df.corr(numeric_only=True),
    cmap=sns.diverging_palette(20,230,as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    cbar_kws={"shrink":0.5},
    annot=True
)
