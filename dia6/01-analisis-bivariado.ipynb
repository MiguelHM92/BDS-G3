# %% [markdown]
# # PASO 1 - IMPORTACIÓN DE LIBRERIAS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # PASO 2 - ESTILOS DE GRAFICOS

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11, 9.4)

penguin_color = {
    'Adelie': '#ff6602ff',
    'Gentoo': '#0f7175ff',
    'Chinstrap': '#c65dc9ff'
}

# %% [markdown]
# # PASO 3 - CARGA DE DATASET

# %%
penguins_df = sns.load_dataset('penguins')
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# # ANALISIS BIVARIADO

# %% [markdown]
# ## RELACIONES ENTRE 2 VARIABLES NUMÉRICAS

# %%
sns.scatterplot(
    data=penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    alpha=1/2,
    s=100
)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.displot(
    data=penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    rug=True
)

# %%
sns.displot(
    data=penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    rug=True,
    kind='kde'
)

# %%
sns.scatterplot(
    data=penguins_df,
    x='flipper_length_mm',
    y='body_mass_g',
    alpha=1/2,
    s=100
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.displot(
    data=penguins_df,
    x='flipper_length_mm',
    y='body_mass_g',
    rug=True
)

# %%
sns.displot(
    data=penguins_df,
    x='flipper_length_mm',
    y='body_mass_g',
    rug=True,
    kind='kde'
)

# %% [markdown]
# ### EJERCICIOS:

# %%
sns.scatterplot(
    data=penguins_df,
    x='bill_length_mm',
    y='body_mass_g',
    alpha=1/2,
    s=100
)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(
    data=penguins_df,
    x='bill_depth_mm',
    y='body_mass_g',
    alpha=1/2,
    s=100
)
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %% [markdown]
# ## RELACIÓN ENTRE VARIABLE NUMERICA Y CATEGORICA

# %% [markdown]
# ### RELACIÓN ENTRE FLIPPER_LENGTH_MM Y SPECIES

# %%
sns.scatterplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color
)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# ### GENERAMOS RUIDO EN LOS VALORES PARA UNA MEJOR VISUALIZACIÓN

# %%
sns.stripplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color
)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# ### UTILIZAMOS BOXPLOT PARA VER EL RANGO

# %%
sns.boxplot(
    data=penguins_df,
    x='flipper_length_mm',
    y='species',
    palette=penguin_color,
    whis=np.inf
)
sns.stripplot(
    data=penguins_df,
    x='flipper_length_mm',
    y='species',
    color='.3'
)
# Out:
# <ipython-input-18-7e73f6b345cd>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# <Axes: xlabel='flipper_length_mm', ylabel='species'>

# %% [markdown]
# ### USAMOS VIOLINPLOT PARA TENER UN GRÁFICO MÁS EXACTO

# %%
sns.violinplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    color='.8'
)

sns.stripplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color
)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# ### USAMOS SWARMPLOT PARA UNA DISTRIBUCIÓN MÁS UNIFORME

# %%
sns.swarmplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color
)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# ### EJERCICIO:

# %%
sns.violinplot(
    data=penguins_df,
    x='sex',
    y='body_mass_g',
    color='.8'
)

sns.stripplot(
    data=penguins_df,
    x='sex',
    y='body_mass_g',
    hue='sex',
)
# Out:
# <Axes: xlabel='sex', ylabel='body_mass_g'>

# %%
sns.swarmplot(
    data=penguins_df,
    x='sex',
    y='body_mass_g',
    hue='sex'
)
# Out:
# <Axes: xlabel='sex', ylabel='body_mass_g'>
